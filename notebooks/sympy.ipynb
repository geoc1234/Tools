# %% [markdown]
# <a href="https://colab.research.google.com/github/geoc1234/Tools/blob/main/notebooks/sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sympy

# %%
import sympy
x = sympy.Symbol('x')

a = sympy.Integral(cos(x)*exp(x), x)
Eq(a, a.doit())
# Out:
# Eq(Integral(exp(x)*cos(x), x), exp(x)*sin(x)/2 + exp(x)*cos(x)/2)

# %%
sympy.sqrt(2)
# Out:
# sqrt(2)

# %%
x, y = sympy.symbols('x y')
eq1 = x**2 + y
eq1 += 1
eq1 += - x
eq1
# Out:
# x**2 - x + y + 1

# %%
sympy.diff(sin(x)*exp(x), x)
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)

# %%
sympy.integrate(cos(x)*exp(x) + exp(x)*sin(x), x)
# Out:
#  x
# ℯ ⋅sin(x)

# %%
y = sympy.Function('y')
t = sympy.Symbol('t')
sympy.dsolve(Eq(y(t).diff(t,t) - y(t),exp(t)),y(t))
# Out:
#            -t   ⎛     t⎞  t
# y(t) = C₂⋅ℯ   + ⎜C₁ + ─⎟⋅ℯ
#                 ⎝     2⎠

# %%
Matrix([[1, 2], [-3, 2]]).eigenvals()
# Out:
# ⎧3   √23⋅ⅈ     3   √23⋅ⅈ   ⎫
# ⎨─ - ─────: 1, ─ + ─────: 1⎬
# ⎩2     2       2     2     ⎭
